# %%
# # SPIKE RASTER 1
import os
import matplotlib.pyplot as plt
import torch

file_name = f'taskA_i3_job0_epoch0_batch0.pth'
data = torch.load(file_name)

spikes = data['spikes'][0,:]
print(spikes.shape)

plt.figure(figsize=(10, 5))
y, x = torch.where(spikes == 1)
plt.scatter(x,y,marker='o', color='black', s=1)

# for neuron, spike_train in enumerate(spikes):
#     #spike times per neuron
#     spike_times = torch.where(spike_train > 0) 
#     plt.vlines(spike_times, neuron - 0.2, neuron + 0.2)
    
plt.title(f'Raster Plot')
plt.xlabel('Time')
plt.ylabel('Neurons')
plt.show()
# Out:
# torch.Size([200, 300])

# %%
outputs = data['outputs'].shape
print(outputs)
# Out:
# torch.Size([25, 300])

# %%
loss = data['task_loss']
print(loss)

rec_weights = data['rec_weights']
print(rec_weights)
# Out:
# 1667.9429931640625
# tensor([[ 0.7430,  0.0000,  0.0000,  ...,  0.0000,  0.0000, -0.0200],
#         [ 0.0000,  0.4104,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#         [ 0.0000,  0.0000,  0.0000,  ...,  0.0000, -0.0200,  0.0000],
#         ...,
#         [ 0.0000,  0.0000,  0.0000,  ...,  0.0000, -0.0114,  0.0000],
#         [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#         [ 0.0000,  0.0000,  0.0000,  ..., -0.0033,  0.0000,  0.0000]])

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# Convert to NumPy for visualization
weight_matrix_np = rec_weights[160:,160:].T.numpy()

# Create a heatmap
plt.figure(figsize=(10, 8))  # Adjust figure size
sns.heatmap(weight_matrix_np, cmap="coolwarm", center=0)  # Blue-red colormap
plt.title("Weight Matrix Connectivity")
plt.xlabel("Neuron Index")
plt.ylabel("Neuron Index")
plt.show()
